# %%
import pandas as pd

# %%
# Get all the csv filepaths and create a list of files
bike_2020_01 = "Resources/JC-202001-citibike-tripdata.csv"
bike_2020_02 = "Resources/JC-202002-citibike-tripdata.csv"
bike_2020_03 = "Resources/JC-202003-citibike-tripdata.csv"
bike_2020_04 = "Resources/JC-202004-citibike-tripdata.csv"
bike_2020_05 = "Resources/JC-202005-citibike-tripdata.csv"
bike_2020_06 = "Resources/JC-202006-citibike-tripdata.csv"
bike_2020_07 = "Resources/JC-202007-citibike-tripdata.csv"
bike_2020_08 = "Resources/JC-202008-citibike-tripdata.csv"
bike_2020_09 = "Resources/JC-202009-citibike-tripdata.csv"
bike_2020_10 = "Resources/JC-202010-citibike-tripdata.csv"
bike_2020_11 = "Resources/JC-202011-citibike-tripdata.csv"
bike_2020_12 = "Resources/JC-202012-citibike-tripdata.csv"

data = [bike_2020_01,bike_2020_02,bike_2020_03,bike_2020_04,bike_2020_05,bike_2020_06,bike_2020_07, bike_2020_08,bike_2020_09,bike_2020_10,bike_2020_11,bike_2020_12]

# %%
#Create a dataframe for the whole year
bike_list = []

for file in data:
    bike_list.append(pd.read_csv(file))

bike_2020 = pd.concat(bike_list, sort=False)
bike_2020
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1               377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2               288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3               435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4               231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...             ...                       ...                       ...
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
# Data types
bike_2020.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# Drop age > 100 years old 
clean_data = bikedata_2020.loc[bikedata_2020["birth year"] > 1920, :]

# reset index
clean_data = clean_data.reset_index(drop = True)

# %%
clean_data
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1                377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2                288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3                435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4                231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...              ...                       ...                       ...
# 336776          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 336777          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 336778          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 336779           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 336780          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#         start station id start station name  start station latitude  \
# ...

# %%
clean_data.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  3.367810e+05     336781.000000           336781.000000
# mean   1.574787e+03       3304.141659               40.722216
# std    1.802533e+04        184.601482                0.007351
# min    6.100000e+01       3184.000000               40.709651
# 25%    3.260000e+02       3195.000000               40.716870
# 50%    6.150000e+02       3209.000000               40.721124
# 75%    1.416000e+03       3276.000000               40.727224
# max    3.261756e+06       3792.000000               40.748716
#
#        start station longitude  end station id  end station latitude  \
# count            336781.000000   336781.000000         336781.000000
# mean                -74.046752     3302.785721             40.721736
# std                   0.011905      190.111644              0.099507
# min                 -74.083639       82.000000              0.000000
# ...

# %%
# Replace gender
# (Zero=unknown; 1=male; 2=female)

# %%
# Export clean_data to a CSV file 

#clean_data.to_csv("Resources/bikedata_2020.csv", index=False)
